# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl?uf=RJ&tipo_interessado=Munic%C3%ADpio'

# %%
r = requests.get(url)

# %%
df = pd.DataFrame(r.json()['items'])

# %%
df
# Out:
#      id_pleito tipo_interessado        interessado  cod_ibge  uf  \
# 0        11340        Município          Nilópolis   3303203  RJ
# 1         5290        Município  Casimiro de Abreu   3301306  RJ
# 2         6363        Município          Rio Claro   3304409  RJ
# 3         9317        Município        Nova Iguaçu   3303500  RJ
# 4         7907        Município           Mesquita   3302858  RJ
# ..         ...              ...                ...       ...  ..
# 231      12014        Município    Cardoso Moreira   3301157  RJ
# 232      23148        Município     Rio de Janeiro   3304557  RJ
# 233      42476        Município        Nova Iguaçu   3303500  RJ
# 234      61653        Município        Teresópolis   3305802  RJ
# 235      36529        Município            Resende   3304201  RJ
#
#                   num_pvl                          status  \
# 0                    None  Arquivado por decurso de prazo
# 1                    None                        Deferido
# 2                    None                    Regularizado
# 3                    None                    Regularizado
# 4                    None                        Deferido
# ..                    ...                             ...
# 231                  None                       Arquivado
# 232  PVL02.000145/2016-66                        Deferido
# 233  PVL02.001006/2020-36                        Deferido
# 234  PVL02.007127/2022-53                        Deferido
# 235  PVL02.005421/2019-25               Deferido (PVL-IF)
#
#              num_processo        data_protocolo  \
# 0    17944.001415/2011-12  2014-12-31T02:00:00Z
# 1    17944.000078/2014-81  2014-11-28T02:00:00Z
# 2    17944.000328/2008-34  2011-06-01T03:00:00Z
# 3    17944.000953/2007-03  2007-06-18T03:00:00Z
# 4    17944.000675/2010-81  2010-09-06T03:00:00Z
# ..                    ...                   ...
# 231  17944.001581/2009-96  2010-05-07T03:00:00Z
# 232  17944.001004/2016-23  2016-08-25T03:00:00Z
# 233  17944.101957/2020-77  2020-06-25T18:44:47Z
# 234  17944.103775/2022-01  2022-10-19T19:18:08Z
# 235                  None                  None
#
#                                          tipo_operacao  \
# 0    Operação contratual interna (com garantia da U...
# 1                          Operação contratual interna
# 2                          Operação contratual interna
# 3                          Operação contratual interna
# 4                          Operação contratual interna
# ..                                                 ...
# 231                        Operação contratual interna
# 232                        Operação contratual interna
# 233                        Operação contratual interna
# 234                        Operação contratual interna
# 235                        Operação contratual interna
#
#                                             finalidade  \
# 0                                  PAC - Contrapartida
# 1    PAC 2 - Pró-Transporte - Pavimentação e Qualif...
# 2           Regularização de Dívida - Energia Elétrica
# 3                     Regularização de Dívida - Outros
# 4                                                PNAFM
# ..                                                 ...
# 231                           Caminho da Escola 2009 A
# 232                                     Infraestrutura
# 233                                     Infraestrutura
# 234                                     Multissetorial
# 235     Aquisição de máquinas, equipamentos e veículos
#
#                          tipo_credor  \
# 0    Instituição Financeira Nacional
# 1    Instituição Financeira Nacional
# 2                Empresa Não Estatal
# 3                Outras Organizações
# 4    Instituição Financeira Nacional
# ..                               ...
# 231  Instituição Financeira Nacional
# 232  Instituição Financeira Nacional
# 233  Instituição Financeira Nacional
# 234  Instituição Financeira Nacional
# 235  Instituição Financeira Nacional
#
#                                                 credor moeda         valor  \
# 0                              Caixa Econômica Federal  Real  1.763904e+06
# 1                              Caixa Econômica Federal  Real  1.502463e+07
# 2                 Light - Serviços de Eletricidade S/A  Real  6.733231e+06
# 3                                      Pessoa Jurídica  Real  1.077467e+06
# 4                              Caixa Econômica Federal  Real  5.106563e+06
# ..                                                 ...   ...           ...
# 231                                Banco do Brasil S/A  Real  9.950000e+05
# 232  Banco Nacional de Desenvolvimento Econômico e ...  Real  8.000000e+08
# 233                            Caixa Econômica Federal  Real  5.400000e+07
# 234     Agência de Fomento do Estado do Rio de Janeiro  Real  3.500000e+07
# 235                                Banco do Brasil S/A  Real  3.082637e+06
#
#      pvl_assoc_divida  pvl_contradado_credor data_status
# 0                   0                      0  10/08/2017
# 1                   1                      0  12/12/2014
# 2                   0                      0  22/07/2011
# 3                   1                      0  02/08/2007
# 4                   1                      0  20/09/2010
# ..                ...                    ...         ...
# 231                 0                      0  21/12/2010
# 232                 1                      0  14/09/2016
# 233                 1                      0  30/06/2020
# 234                 0                      0  21/10/2022
# 235                 0                      1  28/10/2019
#
# [236 rows x 18 columns]

# %%
# 2) Seu código aqui
df['status'].value_counts().head(3)
# Out:
# Deferido        94
# Arquivado       53
# Regularizado    25
# Name: status, dtype: int64

# %%
df['status'].value_counts()
# Out:
# Deferido                                                 94
# Arquivado                                                53
# Regularizado                                             25
# Arquivado por decurso de prazo                           24
# Deferido (PVL-IF)                                        16
# Encaminhado à PGFN com manifestação técnica favorável    14
# Arquivado a pedido                                        6
# Em retificação pelo interessado                           2
# Em retificação pelo interessado (PVL-IF)                  1
# Em retificação pelo credor                                1
# Name: status, dtype: int64

# %%
# 3) Seu código aqui
data_status = df['data_status'].str.split()
data_status
# Out:
# 0      [10/08/2017]
# 1      [12/12/2014]
# 2      [22/07/2011]
# 3      [02/08/2007]
# 4      [20/09/2010]
#            ...
# 231    [21/12/2010]
# 232    [14/09/2016]
# 233    [30/06/2020]
# 234    [21/10/2022]
# 235    [28/10/2019]
# Name: data_status, Length: 236, dtype: object

# %%
# 4) Seu código aqui
data_status.value_counts()
# Out:
# [25/05/2007]    6
# [02/08/2007]    5
# [30/10/2008]    5
# [26/06/2007]    4
# [27/09/2019]    4
#                ..
# [02/12/2014]    1
# [15/07/2010]    1
# [30/10/2014]    1
# [03/01/2012]    1
# [28/10/2019]    1
# Name: data_status, Length: 180, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

# %%
# 2) Seu código aqui

# %%
# 3) Seu código aqui

# %%
# 4) Seu código aqui
